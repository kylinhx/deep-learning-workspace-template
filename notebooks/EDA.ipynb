# %% [markdown]
# # Data

# %%
import os
import matplotlib.pyplot as plt
from PIL import Image

# 获取文件夹中的所有图片文件名
image_folder = 'E:\\个人项目\\deep-learning-workspace-template\\data\\example\\'
image_files = [f for f in os.listdir(image_folder) if os.path.isfile(os.path.join(image_folder, f))]

# 打印图片文件名
print("Images in folder:", image_files)

# 可视化图片
fig = plt.figure(figsize=(10, 10))
columns = 3
rows = 3
for i in range(1, columns*rows +1):
    img = Image.open(os.path.join(image_folder, image_files[i-1]))
    fig.add_subplot(rows, columns, i)
    plt.imshow(img)
# Out:
# Images in folder: ['1.jpg', '2.jpg', '3.jpg', '4.jpg', '5.jpg', '6.jpg']
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 17
#      15 rows = 3
#      16 for i in range(1, columns*rows +1):
# ---> 17     img = Image.open(os.path.join(image_folder, image_files[i-1]))
#      18     fig.add_subplot(rows, columns, i)
#      19     plt.imshow(img)
#
# IndexError: list index out of range
